# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headervalues = ['Vg_set', 'Vtg_set', 'B_set', 'Vd_set', 'Vg', 'Vtg', 
                'Vd', 'Id', 'Vac_real_raw', 'Iac_real_raw', 
                'Vac_imag_raw', 'Iac_imag_raw', 'Vac_R_raw', 
                'Iac_R_raw', 'Vac_p_raw', 'Iac_p_raw', 'Rac', 
                'Rac_inphase', 'G_inphase', 'timestamp']

raw_data = pd.read_csv('data.dat', header=None, delimiter='\t')
raw_data.columns = headervalues
bvalues = np.unique(raw_data['B_set'].values)

# %%
ic_extract = pd.read_csv('data-ic-extract.csv', index_col=0)['0'].values 
ic_zero = np.amax(data)

# %%
bshift = (bvalues[1] - bvalues[0]) * 2

# %%
plt.plot(bvalues + np.ones(len(bvalues)) * bshift, data / iczero)

# %%
np.sin(np.arange(0, 10)) / np.arange(0, 10)
# Out:
# /home/nefta/.virtualenvs/kwant/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([        nan,  0.84147098,  0.45464871,  0.04704   , -0.18920062,
#        -0.19178485, -0.04656925,  0.09385523,  0.12366978,  0.04579094])

# %%
def current_no_edges(phi):
    return 2 * np.sqrt(np.sin( np.pi * phi)**2) / (np.pi * np.abs(phi))

# %%
plt.plot(np.linspace(-4, 4, 100), current_no_edges(np.linspace(-4, 4, 100)))

# %%
W = 1
L = 3

n = 3 #Number of scatterings

ypoints = np.linspace(0, W, 100)
xpoints = np.linspace(0, L, 300)

# %%
#start_point = (0, ypoints[np.random.randint(0, 100)]) #random starting points

points = [(0, ypoints[np.random.randint(0, 100)]), 
]

# %%
points[-1][1]
# Out:
# 0.0

# %%
for i in range(n):
    x = xpoints[np.random.randint(points[-1][0]):]
    points.append((x, 'random'))
# Out:
# 40

# %%
def flip_y(y0):
    if y0 == W:
        return 0
    else: # y0 == 0
        return W
